# %%
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
import torch.utils.data
from keras.preprocessing import text, sequence
from sklearn.metrics import roc_auc_score
from torch import nn, optim
from torch.autograd import Variable
from torchvision import datasets,transforms
from torch.utils.data import Dataset, DataLoader


from sklearn.model_selection import GridSearchCV

# %%
df_train = pd.read_csv('Dataset/train.csv')
df_test = pd.read_csv('Dataset/test.csv')

# %%
columnlist=df_train.columns

# %%
columnlist=columnlist[2:]

# %%
columnlist
# Out:
# Index(['toxic', 'severe_toxic', 'obscene', 'threat', 'insult',
#        'identity_hate'],
#       dtype='object')

# %%
sentence_train=df_train["comment_text"].fillna("CVxTz").values
sentence_test=df_test["comment_text"].fillna("CVxTz").values

# %%
tokenize=text.Tokenizer(num_words=200000)

# %%
tokenize.fit_on_texts(list(sentence_train))

# %%
word_index=tokenize.word_index

# %%
sentence_train1=tokenize.texts_to_sequences(sentence_train)

# %%
sentence_test1=tokenize.texts_to_sequences(sentence_test)

# %%
Input_train=sequence.pad_sequences(sentence_train1,20)

# %%
Input_test=sequence.pad_sequences(sentence_test1,20)

# %%
def Pretrained_embedding(emb_file):
    embedding_index={}
    with open(emb_file,encoding="utf8") as f:
        for line in f:
            values=line.split()
            word=values[0]
            vector=np.asarray(values[1:],dtype="float32")
            embedding_index[word]=vector
    return embedding_index

# %%
embedding_index= Pretrained_embedding("Glove/glove.6B.100d.txt")

# %%
def embedding(word_index,embedding_ind):
    embedding_matrix=np.zeros((len(word_index)+1,100))
    for word,i in word_index.items():
        embedding_vector=embedding_ind.get(word)
        if embedding_vector is not None:
            embedding_matrix[i]=embedding_vector
    return embedding_matrix

# %%
embedding_matrix=embedding(word_index,embedding_index)

# %%
class CustomDataset(Dataset):
    def __init__(self,X,Y=None,Transform=None):
        self.X=X
        self.Y=Y
        self.Transform=Transform
        if self.Transform is not None:
            self.X=self.Transform(self.X)
            if self.Y is not None:
                self.Y=self.Transform(self.Y)
        self.X=torch.from_numpy(self.X).long()
        if self.Y is not None:
            self.Y=Y.values
            self.Y=torch.from_numpy(self.Y).float()
    def __getitem__(self,idx):
        data=self.X[idx]
        if self.Y is not None:
            label=self.Y[idx]
            return data,label
        return data
    def __len__(self):
        return len(self.X)

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.embedding=nn.Embedding(num_embeddings=100000,embedding_dim=100)
        self.embedding.weight.data=torch.Tensor(embedding_matrix)
        self.lstm=nn.LSTM(100,50,1,batch_first=True,bidirectional=True)
        self.hidden=(Variable(torch.zeros(2,1,50)),Variable(torch.zeros(2,1,50)))
        self.maxpool=nn.MaxPool1d(20)
        self.fc=nn.Linear(100,1)
        self.sigmoid=nn.Sigmoid()
    def forward(self,x):
        x=self.embedding(x)
        x,self.hidden=self.lstm(x)
        x=self.maxpool(x)
        x = x.view(x.size(0), -1)
        x=self.fc(x)
        x=self.sigmoid(x)
        return x

# %%
y_test_list=[]

# %%
def train():
    
    

    for column in columnlist:
        Train_set=CustomDataset(Input_train,df_train[column])
        Test_set=CustomDataset(Input_test)
        Train=torch.utils.data.DataLoader(Train_set,batch_size=1000)
        Test=torch.utils.data.DataLoader(Test_set,batch_size=1000)
        model=Net()
        model.train()
        learnin1g_rate = 1e-4
        optimizer = optim.Adam(model.parameters(), lr=learnin1g_rate)
        for batch_idx, (data, target) in enumerate(Train):
            data, target = Variable(data), Variable(target)
            y_pred = model(data)
            loss = F.binary_cross_entropy(y_pred, target)
            print(batch_idx,loss)
            model.zero_grad()
            loss.backward()
            optimizer.step()
        preds=[]
        for data in Test:
            data = Variable(data, volatile=True)
            output = model(data)
            result=output.data
            result=(result>.1).float()
            preds.append(result.numpy())
        y_one_test=np.concatenate(preds,axis=0)
        y_test_list.append(y_one_test)

# %%
train()
# Out:
# C:\Users\penaldo\anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Using a target size (torch.Size([1000])) that is different to the input size (torch.Size([1000, 1])) is deprecated. Please ensure they have the same size.
# 0 tensor(0.7454, grad_fn=<BinaryCrossEntropyBackward>)
# 1 tensor(0.7453, grad_fn=<BinaryCrossEntropyBackward>)
# 2 tensor(0.7420, grad_fn=<BinaryCrossEntropyBackward>)
# 3 tensor(0.7415, grad_fn=<BinaryCrossEntropyBackward>)
# 4 tensor(0.7393, grad_fn=<BinaryCrossEntropyBackward>)
# 5 tensor(0.7365, grad_fn=<BinaryCrossEntropyBackward>)
# 6 tensor(0.7340, grad_fn=<BinaryCrossEntropyBackward>)
# 7 tensor(0.7330, grad_fn=<BinaryCrossEntropyBackward>)
# 8 tensor(0.7300, grad_fn=<BinaryCrossEntropyBackward>)
# 9 tensor(0.7303, grad_fn=<BinaryCrossEntropyBackward>)
# 10 tensor(0.7268, grad_fn=<BinaryCrossEntropyBackward>)
# 11 tensor(0.7266, grad_fn=<BinaryCrossEntropyBackward>)
# 12 tensor(0.7216, grad_fn=<BinaryCrossEntropyBackward>)
# 13 tensor(0.7205, grad_fn=<BinaryCrossEntropyBackward>)
# 14 tensor(0.7166, grad_fn=<BinaryCrossEntropyBackward>)
# 15 tensor(0.7159, grad_fn=<BinaryCrossEntropyBackward>)
# 16 tensor(0.7144, grad_fn=<BinaryCrossEntropyBackward>)
# 17 tensor(0.7104, grad_fn=<BinaryCrossEntropyBackward>)
# 18 tensor(0.7098, grad_fn=<BinaryCrossEntropyBackward>)
# 19 tensor(0.7094, grad_fn=<BinaryCrossEntropyBackward>)
# 20 tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward>)
# 21 tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward>)
# 22 tensor(0.7032, grad_fn=<BinaryCrossEntropyBackward>)
# 23 tensor(0.7017, grad_fn=<BinaryCrossEntropyBackward>)
# 24 tensor(0.6989, grad_fn=<BinaryCrossEntropyBackward>)
# 25 tensor(0.6979, grad_fn=<BinaryCrossEntropyBackward>)
# 26 tensor(0.6954, grad_fn=<BinaryCrossEntropyBackward>)
# 27 tensor(0.6934, grad_fn=<BinaryCrossEntropyBackward>)
# 28 tensor(0.6912, grad_fn=<BinaryCrossEntropyBackward>)
# 29 tensor(0.6897, grad_fn=<BinaryCrossEntropyBackward>)
# 30 tensor(0.6895, grad_fn=<BinaryCrossEntropyBackward>)
# 31 tensor(0.6862, grad_fn=<BinaryCrossEntropyBackward>)
# 32 tensor(0.6846, grad_fn=<BinaryCrossEntropyBackward>)
# 33 tensor(0.6821, grad_fn=<BinaryCrossEntropyBackward>)
# 34 tensor(0.6811, grad_fn=<BinaryCrossEntropyBackward>)
# 35 tensor(0.6791, grad_fn=<BinaryCrossEntropyBackward>)
# 36 tensor(0.6779, grad_fn=<BinaryCrossEntropyBackward>)
# 37 tensor(0.6756, grad_fn=<BinaryCrossEntropyBackward>)
# 38 tensor(0.6728, grad_fn=<BinaryCrossEntropyBackward>)
# 39 tensor(0.6726, grad_fn=<BinaryCrossEntropyBackward>)
# 40 tensor(0.6700, grad_fn=<BinaryCrossEntropyBackward>)
# 41 tensor(0.6673, grad_fn=<BinaryCrossEntropyBackward>)
# 42 tensor(0.6652, grad_fn=<BinaryCrossEntropyBackward>)
# 43 tensor(0.6653, grad_fn=<BinaryCrossEntropyBackward>)
# 44 tensor(0.6624, grad_fn=<BinaryCrossEntropyBackward>)
# 45 tensor(0.6606, grad_fn=<BinaryCrossEntropyBackward>)
# 46 tensor(0.6577, grad_fn=<BinaryCrossEntropyBackward>)
# 47 tensor(0.6561, grad_fn=<BinaryCrossEntropyBackward>)
# 48 tensor(0.6552, grad_fn=<BinaryCrossEntropyBackward>)
# 49 tensor(0.6530, grad_fn=<BinaryCrossEntropyBackward>)
# 50 tensor(0.6523, grad_fn=<BinaryCrossEntropyBackward>)
# 51 tensor(0.6476, grad_fn=<BinaryCrossEntropyBackward>)
# 52 tensor(0.6495, grad_fn=<BinaryCrossEntropyBackward>)
# 53 tensor(0.6457, grad_fn=<BinaryCrossEntropyBackward>)
# 54 tensor(0.6425, grad_fn=<BinaryCrossEntropyBackward>)
# 55 tensor(0.6414, grad_fn=<BinaryCrossEntropyBackward>)
# 56 tensor(0.6411, grad_fn=<BinaryCrossEntropyBackward>)
# 57 tensor(0.6408, grad_fn=<BinaryCrossEntropyBackward>)
# 58 tensor(0.6349, grad_fn=<BinaryCrossEntropyBackward>)
# 59 tensor(0.6327, grad_fn=<BinaryCrossEntropyBackward>)
# 60 tensor(0.6333, grad_fn=<BinaryCrossEntropyBackward>)
# 61 tensor(0.6285, grad_fn=<BinaryCrossEntropyBackward>)
# 62 tensor(0.6299, grad_fn=<BinaryCrossEntropyBackward>)
# 63 tensor(0.6267, grad_fn=<BinaryCrossEntropyBackward>)
# 64 tensor(0.6258, grad_fn=<BinaryCrossEntropyBackward>)
# 65 tensor(0.6197, grad_fn=<BinaryCrossEntropyBackward>)
# 66 tensor(0.6225, grad_fn=<BinaryCrossEntropyBackward>)
# 67 tensor(0.6175, grad_fn=<BinaryCrossEntropyBackward>)
# 68 tensor(0.6184, grad_fn=<BinaryCrossEntropyBackward>)
# 69 tensor(0.6154, grad_fn=<BinaryCrossEntropyBackward>)
# 70 tensor(0.6148, grad_fn=<BinaryCrossEntropyBackward>)
# 71 tensor(0.6133, grad_fn=<BinaryCrossEntropyBackward>)
# 72 tensor(0.6104, grad_fn=<BinaryCrossEntropyBackward>)
# 73 tensor(0.6123, grad_fn=<BinaryCrossEntropyBackward>)
# 74 tensor(0.6054, grad_fn=<BinaryCrossEntropyBackward>)
# 75 tensor(0.6015, grad_fn=<BinaryCrossEntropyBackward>)
# 76 tensor(0.6034, grad_fn=<BinaryCrossEntropyBackward>)
# 77 tensor(0.5973, grad_fn=<BinaryCrossEntropyBackward>)
# 78 tensor(0.5964, grad_fn=<BinaryCrossEntropyBackward>)
# 79 tensor(0.5922, grad_fn=<BinaryCrossEntropyBackward>)
# 80 tensor(0.5961, grad_fn=<BinaryCrossEntropyBackward>)
# 81 tensor(0.5864, grad_fn=<BinaryCrossEntropyBackward>)
# 82 tensor(0.5869, grad_fn=<BinaryCrossEntropyBackward>)
# 83 tensor(0.5899, grad_fn=<BinaryCrossEntropyBackward>)
# 84 tensor(0.5827, grad_fn=<BinaryCrossEntropyBackward>)
# 85 tensor(0.5829, grad_fn=<BinaryCrossEntropyBackward>)
# 86 tensor(0.5854, grad_fn=<BinaryCrossEntropyBackward>)
# 87 tensor(0.5776, grad_fn=<BinaryCrossEntropyBackward>)
# 88 tensor(0.5791, grad_fn=<BinaryCrossEntropyBackward>)
# 89 tensor(0.5739, grad_fn=<BinaryCrossEntropyBackward>)
# 90 tensor(0.5662, grad_fn=<BinaryCrossEntropyBackward>)
# 91 tensor(0.5637, grad_fn=<BinaryCrossEntropyBackward>)
# 92 tensor(0.5623, grad_fn=<BinaryCrossEntropyBackward>)
# 93 tensor(0.5598, grad_fn=<BinaryCrossEntropyBackward>)
# 94 tensor(0.5590, grad_fn=<BinaryCrossEntropyBackward>)
# 95 tensor(0.5634, grad_fn=<BinaryCrossEntropyBackward>)
# 96 tensor(0.5606, grad_fn=<BinaryCrossEntropyBackward>)
# 97 tensor(0.5556, grad_fn=<BinaryCrossEntropyBackward>)
# 98 tensor(0.5530, grad_fn=<BinaryCrossEntropyBackward>)
# 99 tensor(0.5555, grad_fn=<BinaryCrossEntropyBackward>)
# 100 tensor(0.5470, grad_fn=<BinaryCrossEntropyBackward>)
# 101 tensor(0.5533, grad_fn=<BinaryCrossEntropyBackward>)
# 102 tensor(0.5504, grad_fn=<BinaryCrossEntropyBackward>)
# 103 tensor(0.5476, grad_fn=<BinaryCrossEntropyBackward>)
# 104 tensor(0.5412, grad_fn=<BinaryCrossEntropyBackward>)
# 105 tensor(0.5394, grad_fn=<BinaryCrossEntropyBackward>)
# 106 tensor(0.5413, grad_fn=<BinaryCrossEntropyBackward>)
# 107 tensor(0.5360, grad_fn=<BinaryCrossEntropyBackward>)
# 108 tensor(0.5368, grad_fn=<BinaryCrossEntropyBackward>)
# 109 tensor(0.5333, grad_fn=<BinaryCrossEntropyBackward>)
# 110 tensor(0.5256, grad_fn=<BinaryCrossEntropyBackward>)
# 111 tensor(0.5234, grad_fn=<BinaryCrossEntropyBackward>)
# 112 tensor(0.5218, grad_fn=<BinaryCrossEntropyBackward>)
# 113 tensor(0.5230, grad_fn=<BinaryCrossEntropyBackward>)
# 114 tensor(0.5264, grad_fn=<BinaryCrossEntropyBackward>)
# 115 tensor(0.5081, grad_fn=<BinaryCrossEntropyBackward>)
# 116 tensor(0.5211, grad_fn=<BinaryCrossEntropyBackward>)
# 117 tensor(0.5152, grad_fn=<BinaryCrossEntropyBackward>)
# 118 tensor(0.5125, grad_fn=<BinaryCrossEntropyBackward>)
# 119 tensor(0.5108, grad_fn=<BinaryCrossEntropyBackward>)
# 120 tensor(0.5124, grad_fn=<BinaryCrossEntropyBackward>)
# 121 tensor(0.5128, grad_fn=<BinaryCrossEntropyBackward>)
# 122 tensor(0.5038, grad_fn=<BinaryCrossEntropyBackward>)
# 123 tensor(0.5097, grad_fn=<BinaryCrossEntropyBackward>)
# 124 tensor(0.4964, grad_fn=<BinaryCrossEntropyBackward>)
# 125 tensor(0.5026, grad_fn=<BinaryCrossEntropyBackward>)
# 126 tensor(0.4979, grad_fn=<BinaryCrossEntropyBackward>)
# 127 tensor(0.4934, grad_fn=<BinaryCrossEntropyBackward>)
# 128 tensor(0.4901, grad_fn=<BinaryCrossEntropyBackward>)
# 129 tensor(0.4912, grad_fn=<BinaryCrossEntropyBackward>)
# 130 tensor(0.4887, grad_fn=<BinaryCrossEntropyBackward>)
# 131 tensor(0.4909, grad_fn=<BinaryCrossEntropyBackward>)
# 132 tensor(0.4900, grad_fn=<BinaryCrossEntropyBackward>)
# 133 tensor(0.4905, grad_fn=<BinaryCrossEntropyBackward>)
# 134 tensor(0.4815, grad_fn=<BinaryCrossEntropyBackward>)
# 135 tensor(0.4700, grad_fn=<BinaryCrossEntropyBackward>)
# 136 tensor(0.4784, grad_fn=<BinaryCrossEntropyBackward>)
# 137 tensor(0.4661, grad_fn=<BinaryCrossEntropyBackward>)
# 138 tensor(0.4702, grad_fn=<BinaryCrossEntropyBackward>)
# 139 tensor(0.4637, grad_fn=<BinaryCrossEntropyBackward>)
# 140 tensor(0.4618, grad_fn=<BinaryCrossEntropyBackward>)
# 141 tensor(0.4684, grad_fn=<BinaryCrossEntropyBackward>)
# 142 tensor(0.4630, grad_fn=<BinaryCrossEntropyBackward>)
# 143 tensor(0.4549, grad_fn=<BinaryCrossEntropyBackward>)
# 144 tensor(0.4614, grad_fn=<BinaryCrossEntropyBackward>)
# 145 tensor(0.4453, grad_fn=<BinaryCrossEntropyBackward>)
# 146 tensor(0.4675, grad_fn=<BinaryCrossEntropyBackward>)
# 147 tensor(0.4488, grad_fn=<BinaryCrossEntropyBackward>)
# 148 tensor(0.4536, grad_fn=<BinaryCrossEntropyBackward>)
# 149 tensor(0.4603, grad_fn=<BinaryCrossEntropyBackward>)
# 150 tensor(0.4518, grad_fn=<BinaryCrossEntropyBackward>)
# 151 tensor(0.4472, grad_fn=<BinaryCrossEntropyBackward>)
# 152 tensor(0.4500, grad_fn=<BinaryCrossEntropyBackward>)
# 153 tensor(0.4409, grad_fn=<BinaryCrossEntropyBackward>)
# 154 tensor(0.4433, grad_fn=<BinaryCrossEntropyBackward>)
# 155 tensor(0.4445, grad_fn=<BinaryCrossEntropyBackward>)
# 156 tensor(0.4390, grad_fn=<BinaryCrossEntropyBackward>)
# 157 tensor(0.4549, grad_fn=<BinaryCrossEntropyBackward>)
# 158 tensor(0.4315, grad_fn=<BinaryCrossEntropyBackward>)
# C:\Users\penaldo\anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Using a target size (torch.Size([571])) that is different to the input size (torch.Size([571, 1])) is deprecated. Please ensure they have the same size.
# 159 tensor(0.4253, grad_fn=<BinaryCrossEntropyBackward>)
# C:\Users\penaldo\anaconda3\lib\site-packages\ipykernel_launcher.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# 0 tensor(0.6852, grad_fn=<BinaryCrossEntropyBackward>)
# 1 tensor(0.6833, grad_fn=<BinaryCrossEntropyBackward>)
# 2 tensor(0.6793, grad_fn=<BinaryCrossEntropyBackward>)
# 3 tensor(0.6782, grad_fn=<BinaryCrossEntropyBackward>)
# 4 tensor(0.6755, grad_fn=<BinaryCrossEntropyBackward>)
# 5 tensor(0.6737, grad_fn=<BinaryCrossEntropyBackward>)
# 6 tensor(0.6710, grad_fn=<BinaryCrossEntropyBackward>)
# 7 tensor(0.6674, grad_fn=<BinaryCrossEntropyBackward>)
# 8 tensor(0.6649, grad_fn=<BinaryCrossEntropyBackward>)
# 9 tensor(0.6628, grad_fn=<BinaryCrossEntropyBackward>)
# 10 tensor(0.6597, grad_fn=<BinaryCrossEntropyBackward>)
# 11 tensor(0.6563, grad_fn=<BinaryCrossEntropyBackward>)
# 12 tensor(0.6564, grad_fn=<BinaryCrossEntropyBackward>)
# 13 tensor(0.6535, grad_fn=<BinaryCrossEntropyBackward>)
# 14 tensor(0.6504, grad_fn=<BinaryCrossEntropyBackward>)
# 15 tensor(0.6481, grad_fn=<BinaryCrossEntropyBackward>)
# 16 tensor(0.6450, grad_fn=<BinaryCrossEntropyBackward>)
# 17 tensor(0.6438, grad_fn=<BinaryCrossEntropyBackward>)
# 18 tensor(0.6398, grad_fn=<BinaryCrossEntropyBackward>)
# 19 tensor(0.6363, grad_fn=<BinaryCrossEntropyBackward>)
# 20 tensor(0.6346, grad_fn=<BinaryCrossEntropyBackward>)
# 21 tensor(0.6325, grad_fn=<BinaryCrossEntropyBackward>)
# 22 tensor(0.6296, grad_fn=<BinaryCrossEntropyBackward>)
# 23 tensor(0.6256, grad_fn=<BinaryCrossEntropyBackward>)
# 24 tensor(0.6242, grad_fn=<BinaryCrossEntropyBackward>)
# 25 tensor(0.6208, grad_fn=<BinaryCrossEntropyBackward>)
# 26 tensor(0.6180, grad_fn=<BinaryCrossEntropyBackward>)
# 27 tensor(0.6163, grad_fn=<BinaryCrossEntropyBackward>)
# 28 tensor(0.6114, grad_fn=<BinaryCrossEntropyBackward>)
# 29 tensor(0.6108, grad_fn=<BinaryCrossEntropyBackward>)
# 30 tensor(0.6072, grad_fn=<BinaryCrossEntropyBackward>)
# 31 tensor(0.6043, grad_fn=<BinaryCrossEntropyBackward>)
# 32 tensor(0.6015, grad_fn=<BinaryCrossEntropyBackward>)
# 33 tensor(0.5974, grad_fn=<BinaryCrossEntropyBackward>)
# 34 tensor(0.5965, grad_fn=<BinaryCrossEntropyBackward>)
# 35 tensor(0.5938, grad_fn=<BinaryCrossEntropyBackward>)
# 36 tensor(0.5911, grad_fn=<BinaryCrossEntropyBackward>)
# 37 tensor(0.5887, grad_fn=<BinaryCrossEntropyBackward>)
# 38 tensor(0.5876, grad_fn=<BinaryCrossEntropyBackward>)
# 39 tensor(0.5841, grad_fn=<BinaryCrossEntropyBackward>)
# 40 tensor(0.5792, grad_fn=<BinaryCrossEntropyBackward>)
# 41 tensor(0.5755, grad_fn=<BinaryCrossEntropyBackward>)
# 42 tensor(0.5719, grad_fn=<BinaryCrossEntropyBackward>)
# 43 tensor(0.5691, grad_fn=<BinaryCrossEntropyBackward>)
# 44 tensor(0.5664, grad_fn=<BinaryCrossEntropyBackward>)
# 45 tensor(0.5629, grad_fn=<BinaryCrossEntropyBackward>)
# 46 tensor(0.5608, grad_fn=<BinaryCrossEntropyBackward>)
# 47 tensor(0.5578, grad_fn=<BinaryCrossEntropyBackward>)
# 48 tensor(0.5549, grad_fn=<BinaryCrossEntropyBackward>)
# 49 tensor(0.5503, grad_fn=<BinaryCrossEntropyBackward>)
# 50 tensor(0.5472, grad_fn=<BinaryCrossEntropyBackward>)
# 51 tensor(0.5413, grad_fn=<BinaryCrossEntropyBackward>)
# 52 tensor(0.5425, grad_fn=<BinaryCrossEntropyBackward>)
# 53 tensor(0.5385, grad_fn=<BinaryCrossEntropyBackward>)
# 54 tensor(0.5334, grad_fn=<BinaryCrossEntropyBackward>)
# 55 tensor(0.5332, grad_fn=<BinaryCrossEntropyBackward>)
# 56 tensor(0.5308, grad_fn=<BinaryCrossEntropyBackward>)
# 57 tensor(0.5269, grad_fn=<BinaryCrossEntropyBackward>)
# 58 tensor(0.5202, grad_fn=<BinaryCrossEntropyBackward>)
# 59 tensor(0.5186, grad_fn=<BinaryCrossEntropyBackward>)
# 60 tensor(0.5161, grad_fn=<BinaryCrossEntropyBackward>)
# 61 tensor(0.5105, grad_fn=<BinaryCrossEntropyBackward>)
# 62 tensor(0.5082, grad_fn=<BinaryCrossEntropyBackward>)
# 63 tensor(0.5071, grad_fn=<BinaryCrossEntropyBackward>)
# 64 tensor(0.5015, grad_fn=<BinaryCrossEntropyBackward>)
# 65 tensor(0.4988, grad_fn=<BinaryCrossEntropyBackward>)
# 66 tensor(0.4948, grad_fn=<BinaryCrossEntropyBackward>)
# 67 tensor(0.4924, grad_fn=<BinaryCrossEntropyBackward>)
# 68 tensor(0.4907, grad_fn=<BinaryCrossEntropyBackward>)
# 69 tensor(0.4895, grad_fn=<BinaryCrossEntropyBackward>)
# 70 tensor(0.4800, grad_fn=<BinaryCrossEntropyBackward>)
# 71 tensor(0.4843, grad_fn=<BinaryCrossEntropyBackward>)
# 72 tensor(0.4776, grad_fn=<BinaryCrossEntropyBackward>)
# 73 tensor(0.4739, grad_fn=<BinaryCrossEntropyBackward>)
# 74 tensor(0.4708, grad_fn=<BinaryCrossEntropyBackward>)
# 75 tensor(0.4643, grad_fn=<BinaryCrossEntropyBackward>)
# 76 tensor(0.4666, grad_fn=<BinaryCrossEntropyBackward>)
# 77 tensor(0.4587, grad_fn=<BinaryCrossEntropyBackward>)
# 78 tensor(0.4562, grad_fn=<BinaryCrossEntropyBackward>)
# 79 tensor(0.4518, grad_fn=<BinaryCrossEntropyBackward>)
# 80 tensor(0.4501, grad_fn=<BinaryCrossEntropyBackward>)
# 81 tensor(0.4463, grad_fn=<BinaryCrossEntropyBackward>)
# 82 tensor(0.4432, grad_fn=<BinaryCrossEntropyBackward>)
# 83 tensor(0.4413, grad_fn=<BinaryCrossEntropyBackward>)
# 84 tensor(0.4354, grad_fn=<BinaryCrossEntropyBackward>)
# 85 tensor(0.4330, grad_fn=<BinaryCrossEntropyBackward>)
# 86 tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward>)
# 87 tensor(0.4236, grad_fn=<BinaryCrossEntropyBackward>)
# 88 tensor(0.4245, grad_fn=<BinaryCrossEntropyBackward>)
# 89 tensor(0.4199, grad_fn=<BinaryCrossEntropyBackward>)
# 90 tensor(0.4127, grad_fn=<BinaryCrossEntropyBackward>)
# 91 tensor(0.4123, grad_fn=<BinaryCrossEntropyBackward>)
# 92 tensor(0.4066, grad_fn=<BinaryCrossEntropyBackward>)
# 93 tensor(0.4059, grad_fn=<BinaryCrossEntropyBackward>)
# 94 tensor(0.3963, grad_fn=<BinaryCrossEntropyBackward>)
# 95 tensor(0.3964, grad_fn=<BinaryCrossEntropyBackward>)
# 96 tensor(0.3965, grad_fn=<BinaryCrossEntropyBackward>)
# 97 tensor(0.3893, grad_fn=<BinaryCrossEntropyBackward>)
# 98 tensor(0.3905, grad_fn=<BinaryCrossEntropyBackward>)
# 99 tensor(0.3970, grad_fn=<BinaryCrossEntropyBackward>)
# 100 tensor(0.3841, grad_fn=<BinaryCrossEntropyBackward>)
# 101 tensor(0.3849, grad_fn=<BinaryCrossEntropyBackward>)
# 102 tensor(0.3776, grad_fn=<BinaryCrossEntropyBackward>)
# 103 tensor(0.3741, grad_fn=<BinaryCrossEntropyBackward>)
# 104 tensor(0.3683, grad_fn=<BinaryCrossEntropyBackward>)
# 105 tensor(0.3652, grad_fn=<BinaryCrossEntropyBackward>)
# 106 tensor(0.3653, grad_fn=<BinaryCrossEntropyBackward>)
# 107 tensor(0.3614, grad_fn=<BinaryCrossEntropyBackward>)
# 108 tensor(0.3602, grad_fn=<BinaryCrossEntropyBackward>)
# 109 tensor(0.3571, grad_fn=<BinaryCrossEntropyBackward>)
# 110 tensor(0.3527, grad_fn=<BinaryCrossEntropyBackward>)
# 111 tensor(0.3559, grad_fn=<BinaryCrossEntropyBackward>)
# 112 tensor(0.3487, grad_fn=<BinaryCrossEntropyBackward>)
# 113 tensor(0.3505, grad_fn=<BinaryCrossEntropyBackward>)
# 114 tensor(0.3508, grad_fn=<BinaryCrossEntropyBackward>)
# 115 tensor(0.3361, grad_fn=<BinaryCrossEntropyBackward>)
# 116 tensor(0.3431, grad_fn=<BinaryCrossEntropyBackward>)
# 117 tensor(0.3378, grad_fn=<BinaryCrossEntropyBackward>)
# 118 tensor(0.3341, grad_fn=<BinaryCrossEntropyBackward>)
# 119 tensor(0.3327, grad_fn=<BinaryCrossEntropyBackward>)
# 120 tensor(0.3265, grad_fn=<BinaryCrossEntropyBackward>)
# 121 tensor(0.3324, grad_fn=<BinaryCrossEntropyBackward>)
# 122 tensor(0.3201, grad_fn=<BinaryCrossEntropyBackward>)
# 123 tensor(0.3186, grad_fn=<BinaryCrossEntropyBackward>)
# 124 tensor(0.3189, grad_fn=<BinaryCrossEntropyBackward>)
# 125 tensor(0.3165, grad_fn=<BinaryCrossEntropyBackward>)
# 126 tensor(0.3100, grad_fn=<BinaryCrossEntropyBackward>)
# 127 tensor(0.3063, grad_fn=<BinaryCrossEntropyBackward>)
# 128 tensor(0.3065, grad_fn=<BinaryCrossEntropyBackward>)
# 129 tensor(0.3059, grad_fn=<BinaryCrossEntropyBackward>)
# 130 tensor(0.3011, grad_fn=<BinaryCrossEntropyBackward>)
# 131 tensor(0.2986, grad_fn=<BinaryCrossEntropyBackward>)
# 132 tensor(0.2945, grad_fn=<BinaryCrossEntropyBackward>)
# 133 tensor(0.3005, grad_fn=<BinaryCrossEntropyBackward>)
# 134 tensor(0.2865, grad_fn=<BinaryCrossEntropyBackward>)
# 135 tensor(0.2894, grad_fn=<BinaryCrossEntropyBackward>)
# 136 tensor(0.2850, grad_fn=<BinaryCrossEntropyBackward>)
# 137 tensor(0.2805, grad_fn=<BinaryCrossEntropyBackward>)
# 138 tensor(0.2788, grad_fn=<BinaryCrossEntropyBackward>)
# 139 tensor(0.2814, grad_fn=<BinaryCrossEntropyBackward>)
# 140 tensor(0.2776, grad_fn=<BinaryCrossEntropyBackward>)
# 141 tensor(0.2746, grad_fn=<BinaryCrossEntropyBackward>)
# 142 tensor(0.2762, grad_fn=<BinaryCrossEntropyBackward>)
# 143 tensor(0.2709, grad_fn=<BinaryCrossEntropyBackward>)
# 144 tensor(0.2672, grad_fn=<BinaryCrossEntropyBackward>)
# 145 tensor(0.2615, grad_fn=<BinaryCrossEntropyBackward>)
# 146 tensor(0.2674, grad_fn=<BinaryCrossEntropyBackward>)
# 147 tensor(0.2656, grad_fn=<BinaryCrossEntropyBackward>)
# 148 tensor(0.2646, grad_fn=<BinaryCrossEntropyBackward>)
# 149 tensor(0.2562, grad_fn=<BinaryCrossEntropyBackward>)
# 150 tensor(0.2526, grad_fn=<BinaryCrossEntropyBackward>)
# 151 tensor(0.2551, grad_fn=<BinaryCrossEntropyBackward>)
# 152 tensor(0.2458, grad_fn=<BinaryCrossEntropyBackward>)
# 153 tensor(0.2469, grad_fn=<BinaryCrossEntropyBackward>)
# 154 tensor(0.2388, grad_fn=<BinaryCrossEntropyBackward>)
# 155 tensor(0.2458, grad_fn=<BinaryCrossEntropyBackward>)
# 156 tensor(0.2405, grad_fn=<BinaryCrossEntropyBackward>)
# 157 tensor(0.2476, grad_fn=<BinaryCrossEntropyBackward>)
# 158 tensor(0.2393, grad_fn=<BinaryCrossEntropyBackward>)
# 159 tensor(0.2400, grad_fn=<BinaryCrossEntropyBackward>)
# 0 tensor(0.8412, grad_fn=<BinaryCrossEntropyBackward>)
# 1 tensor(0.8382, grad_fn=<BinaryCrossEntropyBackward>)
# 2 tensor(0.8325, grad_fn=<BinaryCrossEntropyBackward>)
# 3 tensor(0.8350, grad_fn=<BinaryCrossEntropyBackward>)
# 4 tensor(0.8276, grad_fn=<BinaryCrossEntropyBackward>)
# 5 tensor(0.8258, grad_fn=<BinaryCrossEntropyBackward>)
# 6 tensor(0.8231, grad_fn=<BinaryCrossEntropyBackward>)
# 7 tensor(0.8197, grad_fn=<BinaryCrossEntropyBackward>)
# 8 tensor(0.8191, grad_fn=<BinaryCrossEntropyBackward>)
# 9 tensor(0.8165, grad_fn=<BinaryCrossEntropyBackward>)
# 10 tensor(0.8123, grad_fn=<BinaryCrossEntropyBackward>)
# 11 tensor(0.8140, grad_fn=<BinaryCrossEntropyBackward>)
# 12 tensor(0.8057, grad_fn=<BinaryCrossEntropyBackward>)
# 13 tensor(0.8039, grad_fn=<BinaryCrossEntropyBackward>)
# 14 tensor(0.7971, grad_fn=<BinaryCrossEntropyBackward>)
# 15 tensor(0.7971, grad_fn=<BinaryCrossEntropyBackward>)
# 16 tensor(0.7945, grad_fn=<BinaryCrossEntropyBackward>)
# 17 tensor(0.7896, grad_fn=<BinaryCrossEntropyBackward>)
# 18 tensor(0.7882, grad_fn=<BinaryCrossEntropyBackward>)
# 19 tensor(0.7884, grad_fn=<BinaryCrossEntropyBackward>)
# 20 tensor(0.7841, grad_fn=<BinaryCrossEntropyBackward>)
# 21 tensor(0.7850, grad_fn=<BinaryCrossEntropyBackward>)
# 22 tensor(0.7802, grad_fn=<BinaryCrossEntropyBackward>)
# 23 tensor(0.7740, grad_fn=<BinaryCrossEntropyBackward>)
# 24 tensor(0.7723, grad_fn=<BinaryCrossEntropyBackward>)
# 25 tensor(0.7719, grad_fn=<BinaryCrossEntropyBackward>)
# 26 tensor(0.7672, grad_fn=<BinaryCrossEntropyBackward>)
# 27 tensor(0.7650, grad_fn=<BinaryCrossEntropyBackward>)
# 28 tensor(0.7627, grad_fn=<BinaryCrossEntropyBackward>)
# 29 tensor(0.7604, grad_fn=<BinaryCrossEntropyBackward>)
# 30 tensor(0.7568, grad_fn=<BinaryCrossEntropyBackward>)
# 31 tensor(0.7576, grad_fn=<BinaryCrossEntropyBackward>)
# 32 tensor(0.7522, grad_fn=<BinaryCrossEntropyBackward>)
# 33 tensor(0.7473, grad_fn=<BinaryCrossEntropyBackward>)
# 34 tensor(0.7481, grad_fn=<BinaryCrossEntropyBackward>)
# 35 tensor(0.7448, grad_fn=<BinaryCrossEntropyBackward>)
# 36 tensor(0.7429, grad_fn=<BinaryCrossEntropyBackward>)
# 37 tensor(0.7405, grad_fn=<BinaryCrossEntropyBackward>)
# 38 tensor(0.7350, grad_fn=<BinaryCrossEntropyBackward>)
# 39 tensor(0.7354, grad_fn=<BinaryCrossEntropyBackward>)
# 40 tensor(0.7329, grad_fn=<BinaryCrossEntropyBackward>)
# 41 tensor(0.7301, grad_fn=<BinaryCrossEntropyBackward>)
# 42 tensor(0.7263, grad_fn=<BinaryCrossEntropyBackward>)
# 43 tensor(0.7270, grad_fn=<BinaryCrossEntropyBackward>)
# 44 tensor(0.7218, grad_fn=<BinaryCrossEntropyBackward>)
# 45 tensor(0.7202, grad_fn=<BinaryCrossEntropyBackward>)
# 46 tensor(0.7180, grad_fn=<BinaryCrossEntropyBackward>)
# 47 tensor(0.7190, grad_fn=<BinaryCrossEntropyBackward>)
# 48 tensor(0.7133, grad_fn=<BinaryCrossEntropyBackward>)
# 49 tensor(0.7110, grad_fn=<BinaryCrossEntropyBackward>)
# 50 tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward>)
# 51 tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward>)
# 52 tensor(0.7029, grad_fn=<BinaryCrossEntropyBackward>)
# 53 tensor(0.7018, grad_fn=<BinaryCrossEntropyBackward>)
# 54 tensor(0.6996, grad_fn=<BinaryCrossEntropyBackward>)
# 55 tensor(0.6988, grad_fn=<BinaryCrossEntropyBackward>)
# 56 tensor(0.6937, grad_fn=<BinaryCrossEntropyBackward>)
# 57 tensor(0.6917, grad_fn=<BinaryCrossEntropyBackward>)
# 58 tensor(0.6909, grad_fn=<BinaryCrossEntropyBackward>)
# 59 tensor(0.6874, grad_fn=<BinaryCrossEntropyBackward>)
# 60 tensor(0.6849, grad_fn=<BinaryCrossEntropyBackward>)
# 61 tensor(0.6810, grad_fn=<BinaryCrossEntropyBackward>)
# 62 tensor(0.6801, grad_fn=<BinaryCrossEntropyBackward>)
# 63 tensor(0.6766, grad_fn=<BinaryCrossEntropyBackward>)
# 64 tensor(0.6759, grad_fn=<BinaryCrossEntropyBackward>)
# 65 tensor(0.6723, grad_fn=<BinaryCrossEntropyBackward>)
# 66 tensor(0.6702, grad_fn=<BinaryCrossEntropyBackward>)
# 67 tensor(0.6684, grad_fn=<BinaryCrossEntropyBackward>)
# 68 tensor(0.6684, grad_fn=<BinaryCrossEntropyBackward>)
# 69 tensor(0.6657, grad_fn=<BinaryCrossEntropyBackward>)
# 70 tensor(0.6604, grad_fn=<BinaryCrossEntropyBackward>)
# 71 tensor(0.6583, grad_fn=<BinaryCrossEntropyBackward>)
# 72 tensor(0.6578, grad_fn=<BinaryCrossEntropyBackward>)
# 73 tensor(0.6552, grad_fn=<BinaryCrossEntropyBackward>)
# 74 tensor(0.6512, grad_fn=<BinaryCrossEntropyBackward>)
# 75 tensor(0.6482, grad_fn=<BinaryCrossEntropyBackward>)
# 76 tensor(0.6483, grad_fn=<BinaryCrossEntropyBackward>)
# 77 tensor(0.6461, grad_fn=<BinaryCrossEntropyBackward>)
# 78 tensor(0.6436, grad_fn=<BinaryCrossEntropyBackward>)
# 79 tensor(0.6369, grad_fn=<BinaryCrossEntropyBackward>)
# 80 tensor(0.6388, grad_fn=<BinaryCrossEntropyBackward>)
# 81 tensor(0.6349, grad_fn=<BinaryCrossEntropyBackward>)
# 82 tensor(0.6315, grad_fn=<BinaryCrossEntropyBackward>)
# 83 tensor(0.6334, grad_fn=<BinaryCrossEntropyBackward>)
# 84 tensor(0.6283, grad_fn=<BinaryCrossEntropyBackward>)
# 85 tensor(0.6281, grad_fn=<BinaryCrossEntropyBackward>)
# 86 tensor(0.6252, grad_fn=<BinaryCrossEntropyBackward>)
# 87 tensor(0.6217, grad_fn=<BinaryCrossEntropyBackward>)
# 88 tensor(0.6177, grad_fn=<BinaryCrossEntropyBackward>)
# 89 tensor(0.6156, grad_fn=<BinaryCrossEntropyBackward>)
# 90 tensor(0.6103, grad_fn=<BinaryCrossEntropyBackward>)
# 91 tensor(0.6085, grad_fn=<BinaryCrossEntropyBackward>)
# 92 tensor(0.6082, grad_fn=<BinaryCrossEntropyBackward>)
# 93 tensor(0.6057, grad_fn=<BinaryCrossEntropyBackward>)
# 94 tensor(0.6021, grad_fn=<BinaryCrossEntropyBackward>)
# 95 tensor(0.6040, grad_fn=<BinaryCrossEntropyBackward>)
# 96 tensor(0.5995, grad_fn=<BinaryCrossEntropyBackward>)
# 97 tensor(0.5953, grad_fn=<BinaryCrossEntropyBackward>)
# 98 tensor(0.5961, grad_fn=<BinaryCrossEntropyBackward>)
# 99 tensor(0.5967, grad_fn=<BinaryCrossEntropyBackward>)
# 100 tensor(0.5890, grad_fn=<BinaryCrossEntropyBackward>)
# 101 tensor(0.5922, grad_fn=<BinaryCrossEntropyBackward>)
# 102 tensor(0.5867, grad_fn=<BinaryCrossEntropyBackward>)
# 103 tensor(0.5852, grad_fn=<BinaryCrossEntropyBackward>)
# 104 tensor(0.5792, grad_fn=<BinaryCrossEntropyBackward>)
# 105 tensor(0.5750, grad_fn=<BinaryCrossEntropyBackward>)
# 106 tensor(0.5720, grad_fn=<BinaryCrossEntropyBackward>)
# 107 tensor(0.5752, grad_fn=<BinaryCrossEntropyBackward>)
# 108 tensor(0.5707, grad_fn=<BinaryCrossEntropyBackward>)
# 109 tensor(0.5688, grad_fn=<BinaryCrossEntropyBackward>)
# 110 tensor(0.5630, grad_fn=<BinaryCrossEntropyBackward>)
# 111 tensor(0.5651, grad_fn=<BinaryCrossEntropyBackward>)
# 112 tensor(0.5643, grad_fn=<BinaryCrossEntropyBackward>)
# 113 tensor(0.5609, grad_fn=<BinaryCrossEntropyBackward>)
# 114 tensor(0.5607, grad_fn=<BinaryCrossEntropyBackward>)
# 115 tensor(0.5466, grad_fn=<BinaryCrossEntropyBackward>)
# 116 tensor(0.5533, grad_fn=<BinaryCrossEntropyBackward>)
# 117 tensor(0.5497, grad_fn=<BinaryCrossEntropyBackward>)
# 118 tensor(0.5465, grad_fn=<BinaryCrossEntropyBackward>)
# 119 tensor(0.5477, grad_fn=<BinaryCrossEntropyBackward>)
# 120 tensor(0.5425, grad_fn=<BinaryCrossEntropyBackward>)
# 121 tensor(0.5419, grad_fn=<BinaryCrossEntropyBackward>)
# 122 tensor(0.5328, grad_fn=<BinaryCrossEntropyBackward>)
# 123 tensor(0.5392, grad_fn=<BinaryCrossEntropyBackward>)
# 124 tensor(0.5354, grad_fn=<BinaryCrossEntropyBackward>)
# 125 tensor(0.5317, grad_fn=<BinaryCrossEntropyBackward>)
# 126 tensor(0.5249, grad_fn=<BinaryCrossEntropyBackward>)
# 127 tensor(0.5233, grad_fn=<BinaryCrossEntropyBackward>)
# 128 tensor(0.5204, grad_fn=<BinaryCrossEntropyBackward>)
# 129 tensor(0.5195, grad_fn=<BinaryCrossEntropyBackward>)
# 130 tensor(0.5150, grad_fn=<BinaryCrossEntropyBackward>)
# 131 tensor(0.5144, grad_fn=<BinaryCrossEntropyBackward>)
# 132 tensor(0.5155, grad_fn=<BinaryCrossEntropyBackward>)
# 133 tensor(0.5164, grad_fn=<BinaryCrossEntropyBackward>)
# 134 tensor(0.5039, grad_fn=<BinaryCrossEntropyBackward>)
# 135 tensor(0.5048, grad_fn=<BinaryCrossEntropyBackward>)
# 136 tensor(0.5037, grad_fn=<BinaryCrossEntropyBackward>)
# 137 tensor(0.4928, grad_fn=<BinaryCrossEntropyBackward>)
# 138 tensor(0.4950, grad_fn=<BinaryCrossEntropyBackward>)
# 139 tensor(0.4942, grad_fn=<BinaryCrossEntropyBackward>)
# 140 tensor(0.4891, grad_fn=<BinaryCrossEntropyBackward>)
# 141 tensor(0.4942, grad_fn=<BinaryCrossEntropyBackward>)
# 142 tensor(0.4858, grad_fn=<BinaryCrossEntropyBackward>)
# 143 tensor(0.4855, grad_fn=<BinaryCrossEntropyBackward>)
# 144 tensor(0.4844, grad_fn=<BinaryCrossEntropyBackward>)
# 145 tensor(0.4742, grad_fn=<BinaryCrossEntropyBackward>)
# 146 tensor(0.4909, grad_fn=<BinaryCrossEntropyBackward>)
# 147 tensor(0.4778, grad_fn=<BinaryCrossEntropyBackward>)
# 148 tensor(0.4797, grad_fn=<BinaryCrossEntropyBackward>)
# 149 tensor(0.4737, grad_fn=<BinaryCrossEntropyBackward>)
# 150 tensor(0.4683, grad_fn=<BinaryCrossEntropyBackward>)
# 151 tensor(0.4624, grad_fn=<BinaryCrossEntropyBackward>)
# 152 tensor(0.4607, grad_fn=<BinaryCrossEntropyBackward>)
# 153 tensor(0.4621, grad_fn=<BinaryCrossEntropyBackward>)
# 154 tensor(0.4591, grad_fn=<BinaryCrossEntropyBackward>)
# 155 tensor(0.4609, grad_fn=<BinaryCrossEntropyBackward>)
# 156 tensor(0.4530, grad_fn=<BinaryCrossEntropyBackward>)
# 157 tensor(0.4636, grad_fn=<BinaryCrossEntropyBackward>)
# 158 tensor(0.4497, grad_fn=<BinaryCrossEntropyBackward>)
# 159 tensor(0.4509, grad_fn=<BinaryCrossEntropyBackward>)
# 0 tensor(0.7789, grad_fn=<BinaryCrossEntropyBackward>)
# 1 tensor(0.7741, grad_fn=<BinaryCrossEntropyBackward>)
# 2 tensor(0.7720, grad_fn=<BinaryCrossEntropyBackward>)
# 3 tensor(0.7676, grad_fn=<BinaryCrossEntropyBackward>)
# 4 tensor(0.7637, grad_fn=<BinaryCrossEntropyBackward>)
# 5 tensor(0.7601, grad_fn=<BinaryCrossEntropyBackward>)
# 6 tensor(0.7571, grad_fn=<BinaryCrossEntropyBackward>)
# 7 tensor(0.7539, grad_fn=<BinaryCrossEntropyBackward>)
# 8 tensor(0.7503, grad_fn=<BinaryCrossEntropyBackward>)
# 9 tensor(0.7467, grad_fn=<BinaryCrossEntropyBackward>)
# 10 tensor(0.7451, grad_fn=<BinaryCrossEntropyBackward>)
# 11 tensor(0.7410, grad_fn=<BinaryCrossEntropyBackward>)
# 12 tensor(0.7378, grad_fn=<BinaryCrossEntropyBackward>)
# 13 tensor(0.7344, grad_fn=<BinaryCrossEntropyBackward>)
# 14 tensor(0.7315, grad_fn=<BinaryCrossEntropyBackward>)
# 15 tensor(0.7286, grad_fn=<BinaryCrossEntropyBackward>)
# 16 tensor(0.7253, grad_fn=<BinaryCrossEntropyBackward>)
# 17 tensor(0.7230, grad_fn=<BinaryCrossEntropyBackward>)
# 18 tensor(0.7198, grad_fn=<BinaryCrossEntropyBackward>)
# 19 tensor(0.7170, grad_fn=<BinaryCrossEntropyBackward>)
# 20 tensor(0.7137, grad_fn=<BinaryCrossEntropyBackward>)
# 21 tensor(0.7100, grad_fn=<BinaryCrossEntropyBackward>)
# 22 tensor(0.7084, grad_fn=<BinaryCrossEntropyBackward>)
# 23 tensor(0.7046, grad_fn=<BinaryCrossEntropyBackward>)
# 24 tensor(0.7024, grad_fn=<BinaryCrossEntropyBackward>)
# 25 tensor(0.6986, grad_fn=<BinaryCrossEntropyBackward>)
# 26 tensor(0.6966, grad_fn=<BinaryCrossEntropyBackward>)
# 27 tensor(0.6936, grad_fn=<BinaryCrossEntropyBackward>)
# 28 tensor(0.6925, grad_fn=<BinaryCrossEntropyBackward>)
# 29 tensor(0.6878, grad_fn=<BinaryCrossEntropyBackward>)
# 30 tensor(0.6850, grad_fn=<BinaryCrossEntropyBackward>)
# 31 tensor(0.6818, grad_fn=<BinaryCrossEntropyBackward>)
# 32 tensor(0.6806, grad_fn=<BinaryCrossEntropyBackward>)
# 33 tensor(0.6763, grad_fn=<BinaryCrossEntropyBackward>)
# 34 tensor(0.6746, grad_fn=<BinaryCrossEntropyBackward>)
# 35 tensor(0.6719, grad_fn=<BinaryCrossEntropyBackward>)
# 36 tensor(0.6698, grad_fn=<BinaryCrossEntropyBackward>)
# 37 tensor(0.6677, grad_fn=<BinaryCrossEntropyBackward>)
# 38 tensor(0.6639, grad_fn=<BinaryCrossEntropyBackward>)
# 39 tensor(0.6617, grad_fn=<BinaryCrossEntropyBackward>)
# 40 tensor(0.6587, grad_fn=<BinaryCrossEntropyBackward>)
# 41 tensor(0.6548, grad_fn=<BinaryCrossEntropyBackward>)
# 42 tensor(0.6532, grad_fn=<BinaryCrossEntropyBackward>)
# 43 tensor(0.6503, grad_fn=<BinaryCrossEntropyBackward>)
# 44 tensor(0.6484, grad_fn=<BinaryCrossEntropyBackward>)
# 45 tensor(0.6457, grad_fn=<BinaryCrossEntropyBackward>)
# 46 tensor(0.6436, grad_fn=<BinaryCrossEntropyBackward>)
# 47 tensor(0.6424, grad_fn=<BinaryCrossEntropyBackward>)
# 48 tensor(0.6391, grad_fn=<BinaryCrossEntropyBackward>)
# 49 tensor(0.6356, grad_fn=<BinaryCrossEntropyBackward>)
# 50 tensor(0.6313, grad_fn=<BinaryCrossEntropyBackward>)
# 51 tensor(0.6300, grad_fn=<BinaryCrossEntropyBackward>)
# 52 tensor(0.6285, grad_fn=<BinaryCrossEntropyBackward>)
# 53 tensor(0.6263, grad_fn=<BinaryCrossEntropyBackward>)
# 54 tensor(0.6227, grad_fn=<BinaryCrossEntropyBackward>)
# 55 tensor(0.6241, grad_fn=<BinaryCrossEntropyBackward>)
# 56 tensor(0.6208, grad_fn=<BinaryCrossEntropyBackward>)
# 57 tensor(0.6169, grad_fn=<BinaryCrossEntropyBackward>)
# 58 tensor(0.6147, grad_fn=<BinaryCrossEntropyBackward>)
# 59 tensor(0.6115, grad_fn=<BinaryCrossEntropyBackward>)
# 60 tensor(0.6103, grad_fn=<BinaryCrossEntropyBackward>)
# 61 tensor(0.6052, grad_fn=<BinaryCrossEntropyBackward>)
# 62 tensor(0.6044, grad_fn=<BinaryCrossEntropyBackward>)
# 63 tensor(0.6024, grad_fn=<BinaryCrossEntropyBackward>)
# 64 tensor(0.5997, grad_fn=<BinaryCrossEntropyBackward>)
# 65 tensor(0.5958, grad_fn=<BinaryCrossEntropyBackward>)
# 66 tensor(0.5946, grad_fn=<BinaryCrossEntropyBackward>)
# 67 tensor(0.5930, grad_fn=<BinaryCrossEntropyBackward>)
# 68 tensor(0.5907, grad_fn=<BinaryCrossEntropyBackward>)
# 69 tensor(0.5901, grad_fn=<BinaryCrossEntropyBackward>)
# 70 tensor(0.5847, grad_fn=<BinaryCrossEntropyBackward>)
# 71 tensor(0.5845, grad_fn=<BinaryCrossEntropyBackward>)
# 72 tensor(0.5826, grad_fn=<BinaryCrossEntropyBackward>)
# 73 tensor(0.5787, grad_fn=<BinaryCrossEntropyBackward>)
# 74 tensor(0.5761, grad_fn=<BinaryCrossEntropyBackward>)
# 75 tensor(0.5742, grad_fn=<BinaryCrossEntropyBackward>)
# 76 tensor(0.5718, grad_fn=<BinaryCrossEntropyBackward>)
# 77 tensor(0.5690, grad_fn=<BinaryCrossEntropyBackward>)
# 78 tensor(0.5670, grad_fn=<BinaryCrossEntropyBackward>)
# 79 tensor(0.5624, grad_fn=<BinaryCrossEntropyBackward>)
# 80 tensor(0.5625, grad_fn=<BinaryCrossEntropyBackward>)
# 81 tensor(0.5595, grad_fn=<BinaryCrossEntropyBackward>)
# 82 tensor(0.5591, grad_fn=<BinaryCrossEntropyBackward>)
# 83 tensor(0.5567, grad_fn=<BinaryCrossEntropyBackward>)
# 84 tensor(0.5504, grad_fn=<BinaryCrossEntropyBackward>)
# 85 tensor(0.5523, grad_fn=<BinaryCrossEntropyBackward>)
# 86 tensor(0.5494, grad_fn=<BinaryCrossEntropyBackward>)
# 87 tensor(0.5446, grad_fn=<BinaryCrossEntropyBackward>)
# 88 tensor(0.5439, grad_fn=<BinaryCrossEntropyBackward>)
# 89 tensor(0.5400, grad_fn=<BinaryCrossEntropyBackward>)
# 90 tensor(0.5347, grad_fn=<BinaryCrossEntropyBackward>)
# 91 tensor(0.5346, grad_fn=<BinaryCrossEntropyBackward>)
# 92 tensor(0.5322, grad_fn=<BinaryCrossEntropyBackward>)
# 93 tensor(0.5305, grad_fn=<BinaryCrossEntropyBackward>)
# 94 tensor(0.5265, grad_fn=<BinaryCrossEntropyBackward>)
# 95 tensor(0.5245, grad_fn=<BinaryCrossEntropyBackward>)
# 96 tensor(0.5258, grad_fn=<BinaryCrossEntropyBackward>)
# 97 tensor(0.5196, grad_fn=<BinaryCrossEntropyBackward>)
# 98 tensor(0.5192, grad_fn=<BinaryCrossEntropyBackward>)
# 99 tensor(0.5186, grad_fn=<BinaryCrossEntropyBackward>)
# 100 tensor(0.5143, grad_fn=<BinaryCrossEntropyBackward>)
# 101 tensor(0.5144, grad_fn=<BinaryCrossEntropyBackward>)
# 102 tensor(0.5075, grad_fn=<BinaryCrossEntropyBackward>)
# 103 tensor(0.5064, grad_fn=<BinaryCrossEntropyBackward>)
# 104 tensor(0.5034, grad_fn=<BinaryCrossEntropyBackward>)
# 105 tensor(0.5008, grad_fn=<BinaryCrossEntropyBackward>)
# 106 tensor(0.4973, grad_fn=<BinaryCrossEntropyBackward>)
# 107 tensor(0.4956, grad_fn=<BinaryCrossEntropyBackward>)
# 108 tensor(0.4938, grad_fn=<BinaryCrossEntropyBackward>)
# 109 tensor(0.4920, grad_fn=<BinaryCrossEntropyBackward>)
# 110 tensor(0.4875, grad_fn=<BinaryCrossEntropyBackward>)
# 111 tensor(0.4887, grad_fn=<BinaryCrossEntropyBackward>)
# 112 tensor(0.4836, grad_fn=<BinaryCrossEntropyBackward>)
# 113 tensor(0.4840, grad_fn=<BinaryCrossEntropyBackward>)
# 114 tensor(0.4828, grad_fn=<BinaryCrossEntropyBackward>)
# 115 tensor(0.4763, grad_fn=<BinaryCrossEntropyBackward>)
# 116 tensor(0.4753, grad_fn=<BinaryCrossEntropyBackward>)
# 117 tensor(0.4734, grad_fn=<BinaryCrossEntropyBackward>)
# 118 tensor(0.4674, grad_fn=<BinaryCrossEntropyBackward>)
# 119 tensor(0.4689, grad_fn=<BinaryCrossEntropyBackward>)
# 120 tensor(0.4620, grad_fn=<BinaryCrossEntropyBackward>)
# 121 tensor(0.4636, grad_fn=<BinaryCrossEntropyBackward>)
# 122 tensor(0.4587, grad_fn=<BinaryCrossEntropyBackward>)
# 123 tensor(0.4564, grad_fn=<BinaryCrossEntropyBackward>)
# 124 tensor(0.4560, grad_fn=<BinaryCrossEntropyBackward>)
# 125 tensor(0.4523, grad_fn=<BinaryCrossEntropyBackward>)
# 126 tensor(0.4487, grad_fn=<BinaryCrossEntropyBackward>)
# 127 tensor(0.4452, grad_fn=<BinaryCrossEntropyBackward>)
# 128 tensor(0.4430, grad_fn=<BinaryCrossEntropyBackward>)
# 129 tensor(0.4425, grad_fn=<BinaryCrossEntropyBackward>)
# 130 tensor(0.4396, grad_fn=<BinaryCrossEntropyBackward>)
# 131 tensor(0.4356, grad_fn=<BinaryCrossEntropyBackward>)
# 132 tensor(0.4313, grad_fn=<BinaryCrossEntropyBackward>)
# 133 tensor(0.4327, grad_fn=<BinaryCrossEntropyBackward>)
# 134 tensor(0.4265, grad_fn=<BinaryCrossEntropyBackward>)
# 135 tensor(0.4247, grad_fn=<BinaryCrossEntropyBackward>)
# 136 tensor(0.4247, grad_fn=<BinaryCrossEntropyBackward>)
# 137 tensor(0.4192, grad_fn=<BinaryCrossEntropyBackward>)
# 138 tensor(0.4162, grad_fn=<BinaryCrossEntropyBackward>)
# 139 tensor(0.4148, grad_fn=<BinaryCrossEntropyBackward>)
# 140 tensor(0.4119, grad_fn=<BinaryCrossEntropyBackward>)
# 141 tensor(0.4125, grad_fn=<BinaryCrossEntropyBackward>)
# 142 tensor(0.4096, grad_fn=<BinaryCrossEntropyBackward>)
# 143 tensor(0.4065, grad_fn=<BinaryCrossEntropyBackward>)
# 144 tensor(0.3997, grad_fn=<BinaryCrossEntropyBackward>)
# 145 tensor(0.3997, grad_fn=<BinaryCrossEntropyBackward>)
# 146 tensor(0.3979, grad_fn=<BinaryCrossEntropyBackward>)
# 147 tensor(0.3968, grad_fn=<BinaryCrossEntropyBackward>)
# 148 tensor(0.3911, grad_fn=<BinaryCrossEntropyBackward>)
# 149 tensor(0.3872, grad_fn=<BinaryCrossEntropyBackward>)
# 150 tensor(0.3840, grad_fn=<BinaryCrossEntropyBackward>)
# 151 tensor(0.3850, grad_fn=<BinaryCrossEntropyBackward>)
# 152 tensor(0.3785, grad_fn=<BinaryCrossEntropyBackward>)
# 153 tensor(0.3812, grad_fn=<BinaryCrossEntropyBackward>)
# 154 tensor(0.3771, grad_fn=<BinaryCrossEntropyBackward>)
# 155 tensor(0.3745, grad_fn=<BinaryCrossEntropyBackward>)
# 156 tensor(0.3724, grad_fn=<BinaryCrossEntropyBackward>)
# 157 tensor(0.3736, grad_fn=<BinaryCrossEntropyBackward>)
# 158 tensor(0.3692, grad_fn=<BinaryCrossEntropyBackward>)
# 159 tensor(0.3657, grad_fn=<BinaryCrossEntropyBackward>)
# 0 tensor(0.6865, grad_fn=<BinaryCrossEntropyBackward>)
# 1 tensor(0.6852, grad_fn=<BinaryCrossEntropyBackward>)
# 2 tensor(0.6842, grad_fn=<BinaryCrossEntropyBackward>)
# 3 tensor(0.6804, grad_fn=<BinaryCrossEntropyBackward>)
# 4 tensor(0.6786, grad_fn=<BinaryCrossEntropyBackward>)
# 5 tensor(0.6788, grad_fn=<BinaryCrossEntropyBackward>)
# 6 tensor(0.6743, grad_fn=<BinaryCrossEntropyBackward>)
# 7 tensor(0.6724, grad_fn=<BinaryCrossEntropyBackward>)
# 8 tensor(0.6718, grad_fn=<BinaryCrossEntropyBackward>)
# 9 tensor(0.6680, grad_fn=<BinaryCrossEntropyBackward>)
# 10 tensor(0.6686, grad_fn=<BinaryCrossEntropyBackward>)
# 11 tensor(0.6655, grad_fn=<BinaryCrossEntropyBackward>)
# 12 tensor(0.6647, grad_fn=<BinaryCrossEntropyBackward>)
# 13 tensor(0.6628, grad_fn=<BinaryCrossEntropyBackward>)
# 14 tensor(0.6616, grad_fn=<BinaryCrossEntropyBackward>)
# 15 tensor(0.6585, grad_fn=<BinaryCrossEntropyBackward>)
# 16 tensor(0.6557, grad_fn=<BinaryCrossEntropyBackward>)
# 17 tensor(0.6561, grad_fn=<BinaryCrossEntropyBackward>)
# 18 tensor(0.6557, grad_fn=<BinaryCrossEntropyBackward>)
# 19 tensor(0.6507, grad_fn=<BinaryCrossEntropyBackward>)
# 20 tensor(0.6492, grad_fn=<BinaryCrossEntropyBackward>)
# 21 tensor(0.6458, grad_fn=<BinaryCrossEntropyBackward>)
# 22 tensor(0.6446, grad_fn=<BinaryCrossEntropyBackward>)
# 23 tensor(0.6418, grad_fn=<BinaryCrossEntropyBackward>)
# 24 tensor(0.6411, grad_fn=<BinaryCrossEntropyBackward>)
# 25 tensor(0.6386, grad_fn=<BinaryCrossEntropyBackward>)
# 26 tensor(0.6367, grad_fn=<BinaryCrossEntropyBackward>)
# 27 tensor(0.6350, grad_fn=<BinaryCrossEntropyBackward>)
# 28 tensor(0.6318, grad_fn=<BinaryCrossEntropyBackward>)
# 29 tensor(0.6302, grad_fn=<BinaryCrossEntropyBackward>)
# 30 tensor(0.6288, grad_fn=<BinaryCrossEntropyBackward>)
# 31 tensor(0.6249, grad_fn=<BinaryCrossEntropyBackward>)
# 32 tensor(0.6243, grad_fn=<BinaryCrossEntropyBackward>)
# 33 tensor(0.6207, grad_fn=<BinaryCrossEntropyBackward>)
# 34 tensor(0.6188, grad_fn=<BinaryCrossEntropyBackward>)
# 35 tensor(0.6190, grad_fn=<BinaryCrossEntropyBackward>)
# 36 tensor(0.6158, grad_fn=<BinaryCrossEntropyBackward>)
# 37 tensor(0.6132, grad_fn=<BinaryCrossEntropyBackward>)
# 38 tensor(0.6110, grad_fn=<BinaryCrossEntropyBackward>)
# 39 tensor(0.6096, grad_fn=<BinaryCrossEntropyBackward>)
# 40 tensor(0.6063, grad_fn=<BinaryCrossEntropyBackward>)
# 41 tensor(0.6026, grad_fn=<BinaryCrossEntropyBackward>)
# 42 tensor(0.6019, grad_fn=<BinaryCrossEntropyBackward>)
# 43 tensor(0.5978, grad_fn=<BinaryCrossEntropyBackward>)
# 44 tensor(0.5967, grad_fn=<BinaryCrossEntropyBackward>)
# 45 tensor(0.5926, grad_fn=<BinaryCrossEntropyBackward>)
# 46 tensor(0.5900, grad_fn=<BinaryCrossEntropyBackward>)
# 47 tensor(0.5885, grad_fn=<BinaryCrossEntropyBackward>)
# 48 tensor(0.5880, grad_fn=<BinaryCrossEntropyBackward>)
# 49 tensor(0.5832, grad_fn=<BinaryCrossEntropyBackward>)
# 50 tensor(0.5808, grad_fn=<BinaryCrossEntropyBackward>)
# 51 tensor(0.5763, grad_fn=<BinaryCrossEntropyBackward>)
# 52 tensor(0.5776, grad_fn=<BinaryCrossEntropyBackward>)
# 53 tensor(0.5760, grad_fn=<BinaryCrossEntropyBackward>)
# 54 tensor(0.5718, grad_fn=<BinaryCrossEntropyBackward>)
# 55 tensor(0.5700, grad_fn=<BinaryCrossEntropyBackward>)
# 56 tensor(0.5691, grad_fn=<BinaryCrossEntropyBackward>)
# 57 tensor(0.5732, grad_fn=<BinaryCrossEntropyBackward>)
# 58 tensor(0.5636, grad_fn=<BinaryCrossEntropyBackward>)
# 59 tensor(0.5554, grad_fn=<BinaryCrossEntropyBackward>)
# 60 tensor(0.5583, grad_fn=<BinaryCrossEntropyBackward>)
# 61 tensor(0.5488, grad_fn=<BinaryCrossEntropyBackward>)
# 62 tensor(0.5515, grad_fn=<BinaryCrossEntropyBackward>)
# 63 tensor(0.5478, grad_fn=<BinaryCrossEntropyBackward>)
# 64 tensor(0.5459, grad_fn=<BinaryCrossEntropyBackward>)
# 65 tensor(0.5405, grad_fn=<BinaryCrossEntropyBackward>)
# 66 tensor(0.5393, grad_fn=<BinaryCrossEntropyBackward>)
# 67 tensor(0.5346, grad_fn=<BinaryCrossEntropyBackward>)
# 68 tensor(0.5385, grad_fn=<BinaryCrossEntropyBackward>)
# 69 tensor(0.5326, grad_fn=<BinaryCrossEntropyBackward>)
# 70 tensor(0.5271, grad_fn=<BinaryCrossEntropyBackward>)
# 71 tensor(0.5341, grad_fn=<BinaryCrossEntropyBackward>)
# 72 tensor(0.5279, grad_fn=<BinaryCrossEntropyBackward>)
# 73 tensor(0.5270, grad_fn=<BinaryCrossEntropyBackward>)
# 74 tensor(0.5157, grad_fn=<BinaryCrossEntropyBackward>)
# 75 tensor(0.5117, grad_fn=<BinaryCrossEntropyBackward>)
# 76 tensor(0.5134, grad_fn=<BinaryCrossEntropyBackward>)
# 77 tensor(0.5059, grad_fn=<BinaryCrossEntropyBackward>)
# 78 tensor(0.5056, grad_fn=<BinaryCrossEntropyBackward>)
# 79 tensor(0.4998, grad_fn=<BinaryCrossEntropyBackward>)
# 80 tensor(0.5040, grad_fn=<BinaryCrossEntropyBackward>)
# 81 tensor(0.4937, grad_fn=<BinaryCrossEntropyBackward>)
# 82 tensor(0.4922, grad_fn=<BinaryCrossEntropyBackward>)
# 83 tensor(0.4965, grad_fn=<BinaryCrossEntropyBackward>)
# 84 tensor(0.4881, grad_fn=<BinaryCrossEntropyBackward>)
# 85 tensor(0.4881, grad_fn=<BinaryCrossEntropyBackward>)
# 86 tensor(0.4860, grad_fn=<BinaryCrossEntropyBackward>)
# 87 tensor(0.4758, grad_fn=<BinaryCrossEntropyBackward>)
# 88 tensor(0.4799, grad_fn=<BinaryCrossEntropyBackward>)
# 89 tensor(0.4704, grad_fn=<BinaryCrossEntropyBackward>)
# 90 tensor(0.4641, grad_fn=<BinaryCrossEntropyBackward>)
# 91 tensor(0.4616, grad_fn=<BinaryCrossEntropyBackward>)
# 92 tensor(0.4590, grad_fn=<BinaryCrossEntropyBackward>)
# 93 tensor(0.4580, grad_fn=<BinaryCrossEntropyBackward>)
# 94 tensor(0.4519, grad_fn=<BinaryCrossEntropyBackward>)
# 95 tensor(0.4624, grad_fn=<BinaryCrossEntropyBackward>)
# 96 tensor(0.4535, grad_fn=<BinaryCrossEntropyBackward>)
# 97 tensor(0.4439, grad_fn=<BinaryCrossEntropyBackward>)
# 98 tensor(0.4479, grad_fn=<BinaryCrossEntropyBackward>)
# 99 tensor(0.4522, grad_fn=<BinaryCrossEntropyBackward>)
# 100 tensor(0.4312, grad_fn=<BinaryCrossEntropyBackward>)
# 101 tensor(0.4478, grad_fn=<BinaryCrossEntropyBackward>)
# 102 tensor(0.4349, grad_fn=<BinaryCrossEntropyBackward>)
# 103 tensor(0.4372, grad_fn=<BinaryCrossEntropyBackward>)
# 104 tensor(0.4235, grad_fn=<BinaryCrossEntropyBackward>)
# 105 tensor(0.4208, grad_fn=<BinaryCrossEntropyBackward>)
# 106 tensor(0.4219, grad_fn=<BinaryCrossEntropyBackward>)
# 107 tensor(0.4163, grad_fn=<BinaryCrossEntropyBackward>)
# 108 tensor(0.4207, grad_fn=<BinaryCrossEntropyBackward>)
# 109 tensor(0.4155, grad_fn=<BinaryCrossEntropyBackward>)
# 110 tensor(0.4114, grad_fn=<BinaryCrossEntropyBackward>)
# 111 tensor(0.4113, grad_fn=<BinaryCrossEntropyBackward>)
# 112 tensor(0.4088, grad_fn=<BinaryCrossEntropyBackward>)
# 113 tensor(0.4130, grad_fn=<BinaryCrossEntropyBackward>)
# 114 tensor(0.4068, grad_fn=<BinaryCrossEntropyBackward>)
# 115 tensor(0.3906, grad_fn=<BinaryCrossEntropyBackward>)
# 116 tensor(0.4065, grad_fn=<BinaryCrossEntropyBackward>)
# 117 tensor(0.3968, grad_fn=<BinaryCrossEntropyBackward>)
# 118 tensor(0.3925, grad_fn=<BinaryCrossEntropyBackward>)
# 119 tensor(0.3894, grad_fn=<BinaryCrossEntropyBackward>)
# 120 tensor(0.3893, grad_fn=<BinaryCrossEntropyBackward>)
# 121 tensor(0.3916, grad_fn=<BinaryCrossEntropyBackward>)
# 122 tensor(0.3808, grad_fn=<BinaryCrossEntropyBackward>)
# 123 tensor(0.3805, grad_fn=<BinaryCrossEntropyBackward>)
# 124 tensor(0.3735, grad_fn=<BinaryCrossEntropyBackward>)
# 125 tensor(0.3772, grad_fn=<BinaryCrossEntropyBackward>)
# 126 tensor(0.3707, grad_fn=<BinaryCrossEntropyBackward>)
# 127 tensor(0.3744, grad_fn=<BinaryCrossEntropyBackward>)
# 128 tensor(0.3678, grad_fn=<BinaryCrossEntropyBackward>)
# 129 tensor(0.3671, grad_fn=<BinaryCrossEntropyBackward>)
# 130 tensor(0.3648, grad_fn=<BinaryCrossEntropyBackward>)
# 131 tensor(0.3612, grad_fn=<BinaryCrossEntropyBackward>)
# 132 tensor(0.3633, grad_fn=<BinaryCrossEntropyBackward>)
# 133 tensor(0.3711, grad_fn=<BinaryCrossEntropyBackward>)
# 134 tensor(0.3484, grad_fn=<BinaryCrossEntropyBackward>)
# 135 tensor(0.3530, grad_fn=<BinaryCrossEntropyBackward>)
# 136 tensor(0.3602, grad_fn=<BinaryCrossEntropyBackward>)
# 137 tensor(0.3305, grad_fn=<BinaryCrossEntropyBackward>)
# 138 tensor(0.3402, grad_fn=<BinaryCrossEntropyBackward>)
# 139 tensor(0.3371, grad_fn=<BinaryCrossEntropyBackward>)
# 140 tensor(0.3310, grad_fn=<BinaryCrossEntropyBackward>)
# 141 tensor(0.3367, grad_fn=<BinaryCrossEntropyBackward>)
# 142 tensor(0.3296, grad_fn=<BinaryCrossEntropyBackward>)
# 143 tensor(0.3358, grad_fn=<BinaryCrossEntropyBackward>)
# 144 tensor(0.3427, grad_fn=<BinaryCrossEntropyBackward>)
# 145 tensor(0.3199, grad_fn=<BinaryCrossEntropyBackward>)
# 146 tensor(0.3453, grad_fn=<BinaryCrossEntropyBackward>)
# 147 tensor(0.3358, grad_fn=<BinaryCrossEntropyBackward>)
# 148 tensor(0.3361, grad_fn=<BinaryCrossEntropyBackward>)
# 149 tensor(0.3212, grad_fn=<BinaryCrossEntropyBackward>)
# 150 tensor(0.3288, grad_fn=<BinaryCrossEntropyBackward>)
# 151 tensor(0.3186, grad_fn=<BinaryCrossEntropyBackward>)
# 152 tensor(0.3106, grad_fn=<BinaryCrossEntropyBackward>)
# 153 tensor(0.3098, grad_fn=<BinaryCrossEntropyBackward>)
# 154 tensor(0.3083, grad_fn=<BinaryCrossEntropyBackward>)
# 155 tensor(0.3098, grad_fn=<BinaryCrossEntropyBackward>)
# 156 tensor(0.3059, grad_fn=<BinaryCrossEntropyBackward>)
# 157 tensor(0.3169, grad_fn=<BinaryCrossEntropyBackward>)
# 158 tensor(0.3043, grad_fn=<BinaryCrossEntropyBackward>)
# 159 tensor(0.2986, grad_fn=<BinaryCrossEntropyBackward>)
# 0 tensor(0.7325, grad_fn=<BinaryCrossEntropyBackward>)
# 1 tensor(0.7275, grad_fn=<BinaryCrossEntropyBackward>)
# 2 tensor(0.7248, grad_fn=<BinaryCrossEntropyBackward>)
# 3 tensor(0.7207, grad_fn=<BinaryCrossEntropyBackward>)
# 4 tensor(0.7172, grad_fn=<BinaryCrossEntropyBackward>)
# 5 tensor(0.7151, grad_fn=<BinaryCrossEntropyBackward>)
# 6 tensor(0.7112, grad_fn=<BinaryCrossEntropyBackward>)
# 7 tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward>)
# 8 tensor(0.7027, grad_fn=<BinaryCrossEntropyBackward>)
# 9 tensor(0.6993, grad_fn=<BinaryCrossEntropyBackward>)
# 10 tensor(0.6969, grad_fn=<BinaryCrossEntropyBackward>)
# 11 tensor(0.6926, grad_fn=<BinaryCrossEntropyBackward>)
# 12 tensor(0.6914, grad_fn=<BinaryCrossEntropyBackward>)
# 13 tensor(0.6851, grad_fn=<BinaryCrossEntropyBackward>)
# 14 tensor(0.6819, grad_fn=<BinaryCrossEntropyBackward>)
# 15 tensor(0.6793, grad_fn=<BinaryCrossEntropyBackward>)
# 16 tensor(0.6754, grad_fn=<BinaryCrossEntropyBackward>)
# 17 tensor(0.6741, grad_fn=<BinaryCrossEntropyBackward>)
# 18 tensor(0.6702, grad_fn=<BinaryCrossEntropyBackward>)
# 19 tensor(0.6673, grad_fn=<BinaryCrossEntropyBackward>)
# 20 tensor(0.6639, grad_fn=<BinaryCrossEntropyBackward>)
# 21 tensor(0.6594, grad_fn=<BinaryCrossEntropyBackward>)
# 22 tensor(0.6567, grad_fn=<BinaryCrossEntropyBackward>)
# 23 tensor(0.6527, grad_fn=<BinaryCrossEntropyBackward>)
# 24 tensor(0.6513, grad_fn=<BinaryCrossEntropyBackward>)
# 25 tensor(0.6478, grad_fn=<BinaryCrossEntropyBackward>)
# 26 tensor(0.6414, grad_fn=<BinaryCrossEntropyBackward>)
# 27 tensor(0.6395, grad_fn=<BinaryCrossEntropyBackward>)
# 28 tensor(0.6376, grad_fn=<BinaryCrossEntropyBackward>)
# 29 tensor(0.6334, grad_fn=<BinaryCrossEntropyBackward>)
# 30 tensor(0.6308, grad_fn=<BinaryCrossEntropyBackward>)
# 31 tensor(0.6270, grad_fn=<BinaryCrossEntropyBackward>)
# 32 tensor(0.6249, grad_fn=<BinaryCrossEntropyBackward>)
# 33 tensor(0.6188, grad_fn=<BinaryCrossEntropyBackward>)
# 34 tensor(0.6183, grad_fn=<BinaryCrossEntropyBackward>)
# 35 tensor(0.6146, grad_fn=<BinaryCrossEntropyBackward>)
# 36 tensor(0.6132, grad_fn=<BinaryCrossEntropyBackward>)
# 37 tensor(0.6070, grad_fn=<BinaryCrossEntropyBackward>)
# 38 tensor(0.6029, grad_fn=<BinaryCrossEntropyBackward>)
# 39 tensor(0.6025, grad_fn=<BinaryCrossEntropyBackward>)
# 40 tensor(0.5971, grad_fn=<BinaryCrossEntropyBackward>)
# 41 tensor(0.5934, grad_fn=<BinaryCrossEntropyBackward>)
# 42 tensor(0.5894, grad_fn=<BinaryCrossEntropyBackward>)
# 43 tensor(0.5868, grad_fn=<BinaryCrossEntropyBackward>)
# 44 tensor(0.5828, grad_fn=<BinaryCrossEntropyBackward>)
# 45 tensor(0.5810, grad_fn=<BinaryCrossEntropyBackward>)
# 46 tensor(0.5776, grad_fn=<BinaryCrossEntropyBackward>)
# 47 tensor(0.5743, grad_fn=<BinaryCrossEntropyBackward>)
# 48 tensor(0.5715, grad_fn=<BinaryCrossEntropyBackward>)
# 49 tensor(0.5651, grad_fn=<BinaryCrossEntropyBackward>)
# 50 tensor(0.5608, grad_fn=<BinaryCrossEntropyBackward>)
# 51 tensor(0.5571, grad_fn=<BinaryCrossEntropyBackward>)
# 52 tensor(0.5573, grad_fn=<BinaryCrossEntropyBackward>)
# 53 tensor(0.5531, grad_fn=<BinaryCrossEntropyBackward>)
# 54 tensor(0.5489, grad_fn=<BinaryCrossEntropyBackward>)
# 55 tensor(0.5491, grad_fn=<BinaryCrossEntropyBackward>)
# 56 tensor(0.5443, grad_fn=<BinaryCrossEntropyBackward>)
# 57 tensor(0.5411, grad_fn=<BinaryCrossEntropyBackward>)
# 58 tensor(0.5350, grad_fn=<BinaryCrossEntropyBackward>)
# 59 tensor(0.5324, grad_fn=<BinaryCrossEntropyBackward>)
# 60 tensor(0.5310, grad_fn=<BinaryCrossEntropyBackward>)
# 61 tensor(0.5257, grad_fn=<BinaryCrossEntropyBackward>)
# 62 tensor(0.5233, grad_fn=<BinaryCrossEntropyBackward>)
# 63 tensor(0.5225, grad_fn=<BinaryCrossEntropyBackward>)
# 64 tensor(0.5160, grad_fn=<BinaryCrossEntropyBackward>)
# 65 tensor(0.5117, grad_fn=<BinaryCrossEntropyBackward>)
# 66 tensor(0.5103, grad_fn=<BinaryCrossEntropyBackward>)
# 67 tensor(0.5064, grad_fn=<BinaryCrossEntropyBackward>)
# 68 tensor(0.5019, grad_fn=<BinaryCrossEntropyBackward>)
# 69 tensor(0.5001, grad_fn=<BinaryCrossEntropyBackward>)
# 70 tensor(0.4940, grad_fn=<BinaryCrossEntropyBackward>)
# 71 tensor(0.4931, grad_fn=<BinaryCrossEntropyBackward>)
# 72 tensor(0.4921, grad_fn=<BinaryCrossEntropyBackward>)
# 73 tensor(0.4864, grad_fn=<BinaryCrossEntropyBackward>)
# 74 tensor(0.4812, grad_fn=<BinaryCrossEntropyBackward>)
# 75 tensor(0.4766, grad_fn=<BinaryCrossEntropyBackward>)
# 76 tensor(0.4761, grad_fn=<BinaryCrossEntropyBackward>)
# 77 tensor(0.4730, grad_fn=<BinaryCrossEntropyBackward>)
# 78 tensor(0.4681, grad_fn=<BinaryCrossEntropyBackward>)
# 79 tensor(0.4656, grad_fn=<BinaryCrossEntropyBackward>)
# 80 tensor(0.4652, grad_fn=<BinaryCrossEntropyBackward>)
# 81 tensor(0.4567, grad_fn=<BinaryCrossEntropyBackward>)
# 82 tensor(0.4576, grad_fn=<BinaryCrossEntropyBackward>)
# 83 tensor(0.4537, grad_fn=<BinaryCrossEntropyBackward>)
# 84 tensor(0.4445, grad_fn=<BinaryCrossEntropyBackward>)
# 85 tensor(0.4443, grad_fn=<BinaryCrossEntropyBackward>)
# 86 tensor(0.4448, grad_fn=<BinaryCrossEntropyBackward>)
# 87 tensor(0.4337, grad_fn=<BinaryCrossEntropyBackward>)
# 88 tensor(0.4330, grad_fn=<BinaryCrossEntropyBackward>)
# 89 tensor(0.4278, grad_fn=<BinaryCrossEntropyBackward>)
# 90 tensor(0.4202, grad_fn=<BinaryCrossEntropyBackward>)
# 91 tensor(0.4208, grad_fn=<BinaryCrossEntropyBackward>)
# 92 tensor(0.4145, grad_fn=<BinaryCrossEntropyBackward>)
# 93 tensor(0.4130, grad_fn=<BinaryCrossEntropyBackward>)
# 94 tensor(0.4104, grad_fn=<BinaryCrossEntropyBackward>)
# 95 tensor(0.4102, grad_fn=<BinaryCrossEntropyBackward>)
# 96 tensor(0.4049, grad_fn=<BinaryCrossEntropyBackward>)
# 97 tensor(0.3998, grad_fn=<BinaryCrossEntropyBackward>)
# 98 tensor(0.4014, grad_fn=<BinaryCrossEntropyBackward>)
# 99 tensor(0.3997, grad_fn=<BinaryCrossEntropyBackward>)
# 100 tensor(0.3902, grad_fn=<BinaryCrossEntropyBackward>)
# 101 tensor(0.3909, grad_fn=<BinaryCrossEntropyBackward>)
# 102 tensor(0.3818, grad_fn=<BinaryCrossEntropyBackward>)
# 103 tensor(0.3834, grad_fn=<BinaryCrossEntropyBackward>)
# 104 tensor(0.3741, grad_fn=<BinaryCrossEntropyBackward>)
# 105 tensor(0.3702, grad_fn=<BinaryCrossEntropyBackward>)
# 106 tensor(0.3699, grad_fn=<BinaryCrossEntropyBackward>)
# 107 tensor(0.3653, grad_fn=<BinaryCrossEntropyBackward>)
# 108 tensor(0.3654, grad_fn=<BinaryCrossEntropyBackward>)
# 109 tensor(0.3602, grad_fn=<BinaryCrossEntropyBackward>)
# 110 tensor(0.3554, grad_fn=<BinaryCrossEntropyBackward>)
# 111 tensor(0.3541, grad_fn=<BinaryCrossEntropyBackward>)
# 112 tensor(0.3467, grad_fn=<BinaryCrossEntropyBackward>)
# 113 tensor(0.3455, grad_fn=<BinaryCrossEntropyBackward>)
# 114 tensor(0.3445, grad_fn=<BinaryCrossEntropyBackward>)
# 115 tensor(0.3396, grad_fn=<BinaryCrossEntropyBackward>)
# 116 tensor(0.3433, grad_fn=<BinaryCrossEntropyBackward>)
# 117 tensor(0.3381, grad_fn=<BinaryCrossEntropyBackward>)
# 118 tensor(0.3332, grad_fn=<BinaryCrossEntropyBackward>)
# 119 tensor(0.3282, grad_fn=<BinaryCrossEntropyBackward>)
# 120 tensor(0.3196, grad_fn=<BinaryCrossEntropyBackward>)
# 121 tensor(0.3301, grad_fn=<BinaryCrossEntropyBackward>)
# 122 tensor(0.3164, grad_fn=<BinaryCrossEntropyBackward>)
# 123 tensor(0.3128, grad_fn=<BinaryCrossEntropyBackward>)
# 124 tensor(0.3129, grad_fn=<BinaryCrossEntropyBackward>)
# 125 tensor(0.3084, grad_fn=<BinaryCrossEntropyBackward>)
# 126 tensor(0.3035, grad_fn=<BinaryCrossEntropyBackward>)
# 127 tensor(0.3051, grad_fn=<BinaryCrossEntropyBackward>)
# 128 tensor(0.2979, grad_fn=<BinaryCrossEntropyBackward>)
# 129 tensor(0.2990, grad_fn=<BinaryCrossEntropyBackward>)
# 130 tensor(0.2984, grad_fn=<BinaryCrossEntropyBackward>)
# 131 tensor(0.2887, grad_fn=<BinaryCrossEntropyBackward>)
# 132 tensor(0.2942, grad_fn=<BinaryCrossEntropyBackward>)
# 133 tensor(0.2904, grad_fn=<BinaryCrossEntropyBackward>)
# 134 tensor(0.2847, grad_fn=<BinaryCrossEntropyBackward>)
# 135 tensor(0.2840, grad_fn=<BinaryCrossEntropyBackward>)
# 136 tensor(0.2806, grad_fn=<BinaryCrossEntropyBackward>)
# 137 tensor(0.2753, grad_fn=<BinaryCrossEntropyBackward>)
# 138 tensor(0.2769, grad_fn=<BinaryCrossEntropyBackward>)
# 139 tensor(0.2739, grad_fn=<BinaryCrossEntropyBackward>)
# 140 tensor(0.2648, grad_fn=<BinaryCrossEntropyBackward>)
# 141 tensor(0.2687, grad_fn=<BinaryCrossEntropyBackward>)
# 142 tensor(0.2693, grad_fn=<BinaryCrossEntropyBackward>)
# 143 tensor(0.2624, grad_fn=<BinaryCrossEntropyBackward>)
# 144 tensor(0.2639, grad_fn=<BinaryCrossEntropyBackward>)
# 145 tensor(0.2552, grad_fn=<BinaryCrossEntropyBackward>)
# 146 tensor(0.2592, grad_fn=<BinaryCrossEntropyBackward>)
# 147 tensor(0.2490, grad_fn=<BinaryCrossEntropyBackward>)
# 148 tensor(0.2543, grad_fn=<BinaryCrossEntropyBackward>)
# 149 tensor(0.2491, grad_fn=<BinaryCrossEntropyBackward>)
# 150 tensor(0.2450, grad_fn=<BinaryCrossEntropyBackward>)
# 151 tensor(0.2454, grad_fn=<BinaryCrossEntropyBackward>)
# 152 tensor(0.2389, grad_fn=<BinaryCrossEntropyBackward>)
# 153 tensor(0.2409, grad_fn=<BinaryCrossEntropyBackward>)
# 154 tensor(0.2388, grad_fn=<BinaryCrossEntropyBackward>)
# 155 tensor(0.2385, grad_fn=<BinaryCrossEntropyBackward>)
# 156 tensor(0.2302, grad_fn=<BinaryCrossEntropyBackward>)
# 157 tensor(0.2349, grad_fn=<BinaryCrossEntropyBackward>)
# 158 tensor(0.2337, grad_fn=<BinaryCrossEntropyBackward>)
# 159 tensor(0.2392, grad_fn=<BinaryCrossEntropyBackward>)

# %%
y_test=np.concatenate(y_test_list,axis=1)

# %%
sample_submission = pd.read_csv("Dataset/sample_submission.csv")
sample_submission[columnlist] = y_test
sample_submission.to_csv("submission.csv", index=False)

# %%
len(y_test)
# Out:
# 153164
